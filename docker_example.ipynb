# %%
import libpysal as ps
print(ps.__version__)
# Out:
# 4.2.0dev

# %%
import geopandas as gpd

# %%
pth = ps.examples.get_path('south.shp')

# %%
# %matplotlib inline

# %%
gdf = gpd.read_file(pth)

# %%
gdf.head()
# Out:
#    FIPSNO        NAME     STATE_NAME STATE_FIPS CNTY_FIPS   FIPS  STFIPS  \
# 0   54029     Hancock  West Virginia         54       029  54029      54
# 1   54009      Brooke  West Virginia         54       009  54009      54
# 2   54069        Ohio  West Virginia         54       069  54069      54
# 3   54051    Marshall  West Virginia         54       051  54051      54
# 4   10003  New Castle       Delaware         10       003  10003      10
#
#    COFIPS  SOUTH      HR60  ...      BLK90      GI59      GI69      GI79  \
# 0      29      1  1.682864  ...   2.557262  0.223645  0.295377  0.332251
# 1       9      1  4.607233  ...   0.748370  0.220407  0.318453  0.314165
# 2      69      1  0.974132  ...   3.310334  0.272398  0.358454  0.376963
# 3      51      1  0.876248  ...   0.546097  0.227647  0.319580  0.320953
# 4       3      1  4.228385  ...  16.480294  0.256106  0.329678  0.365830
#
#        GI89       FH60  FH70       FH80       FH90  \
# ...

# %%
gdf.plot()

# %%
wv = gdf[gdf.STATE_NAME=='West Virginia']

# %%
wv.plot()

# %%
wv.plot(column='HR60')

# %%
wv.plot(column='HR60',scheme='Equal_Interval')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/geopandas/plotting.py in _mapclassify_choro(values, scheme, **classification_kwds)
#     564     try:
# --> 565         import mapclassify.classifiers
#     566     except ImportError:
#
# ModuleNotFoundError: No module named 'mapclassify'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-11-ee7ec8e48a73> in <module>
# ----> 1 wv.plot(column='HR60',scheme='Equal_Interval')
#
# /opt/conda/lib/python3.7/site-packages/geopandas/geodataframe.py in plot(self, *args, **kwargs)
#     548         from there.
#     549         """
# --> 550         return plot_dataframe(self, *args, **kwargs)
#     551
#     552     plot.__doc__ = plot_dataframe.__doc__
#
# ...
